# %%
import numpy as np
import pandas as pd

# %%
# Question 1
data = {'Name': ['Vishwajeet','Varun','Yash'] ,'Age': [21,20,20] ,'Mail-id': ['vishwajeet@gmail.com','varunvk@gmail.com','yash@gmail.com'],'Phone no':[9485261372,7548963210,8547901236]}
df = pd.DataFrame(data)
print(df)
# Out:
#          Name  Age               Mail-id    Phone no
# 0  Vishwajeet   21  vishwajeet@gmail.com  9485261372
# 1       Varun   20     varunvk@gmail.com  7548963210
# 2        Yash   20        yash@gmail.com  8547901236

# %%
# Question 2(a)
df = pd.read_csv('data/weather.csv')
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0          NW           30.0         SW  ...          29       1019.7
# 1         ENE           39.0          E  ...          36       1012.4
# 2          NW           85.0          N  ...          69       1009.5
# 3          NW           54.0        WNW  ...          56       1005.5
# 4         SSE           50.0        SSE  ...          49       1018.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
# Question 2(b)
df.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0          NW           30.0         SW  ...          29       1019.7
# ...

# %%
# Question 2(c)
print(df['Rainfall'].sum())
print('\n')
print(df['Rainfall'].mean())
print('\n')
print(df['Rainfall'].std())
print('\n')
print(df['Rainfall'].describe())
# Out:
# 522.8
#
#
# 1.4284153005464482
#
#
# 4.225799585804068
#
#
# count    366.000000
# mean       1.428415
# std        4.225800
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.200000
# max       39.800000
# Name: Rainfall, dtype: float64

# %%
# Question 2(d)
df.tail()
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 361         NNW           76.0        SSE  ...          15       1016.1
# 362           N           48.0        NNW  ...          22       1020.0
# 363         ESE           43.0        ENE  ...          47       1024.0
# 364          NW           46.0        SSW  ...          39       1021.0
# 365          NW           78.0         NW  ...          13       1009.6
#
# ...

# %%
# Question 2(e)
data = pd.read_csv('data/weather.csv')
df1 = pd.DataFrame(data,columns=['MinTemp'])
print(df1.describe())
# Out:
#           MinTemp
# count  366.000000
# mean     7.265574
# std      6.025800
# min     -5.300000
# 25%      2.300000
# 50%      7.450000
# 75%     12.500000
# max     20.900000
